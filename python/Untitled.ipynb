# %%
import pylab as pl
import casadi as ca
import numpy as np
import pandas
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
print(ca.__version__)
# Out:
# 3.3.0

# %%
# def f(x, y):
#     return np.sin(np.sqrt(x ** 2 + y ** 2))

f = lambda x,y: x**3 - y

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# xmin = -10
# xmax = 10
# ymin = -10
# ymax = 10
# points = 100
# x = pl.linspace(xmin, xmax, points+1)
# y = pl.linspace(ymin, ymax, points+1)

# %%
ax = plt.axes(projection='3d')

#ax.plot3D(X,Y,Z)
#ax.plot_wireframe(x,y,x*y)

ax.contour3D(X, Y, Z, 1000)#, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
